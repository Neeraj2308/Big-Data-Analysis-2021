# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeraj2308/Big-Data-Analysis-2021/blob/main/panda_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/Neeraj2308/Big-Data-Analysis-2021/main/Data_pd.csv"

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Duration   32 non-null     int64
#  1   Date       31 non-null     object
#  2   Pulse      32 non-null     int64
#  3   Max Pulse  32 non-null     int64
#  4   Calories   30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Max Pulse  Calories
# 0        60  '2020/12/01'    110        130     409.1
# 1        60  '2020/12/02'    117        145     479.0
# 2        60  '2020/12/03'    103        135     340.0
# 3        45  '2020/12/04'    109        175     282.4
# 4        45  '2020/12/05'    117        148     406.0

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 27        60  '2020/12/27'     92        118     241.0
# 28        60  '2020/12/28'    103        132       NaN
# 29        60  '2020/12/29'    100        132     280.0
# 30        60  '2020/12/30'    102        129     380.3
# 31        60  '2020/12/31'     92        115     243.0

# %%
df
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 0         60  '2020/12/01'    110        130     409.1
# 1         60  '2020/12/02'    117        145     479.0
# 2         60  '2020/12/03'    103        135     340.0
# 3         45  '2020/12/04'    109        175     282.4
# 4         45  '2020/12/05'    117        148     406.0
# 5         60  '2020/12/06'    102        127     300.0
# 6         60  '2020/12/07'    110        136     374.0
# 7        450  '2020/12/08'    104        134     253.3
# 8         30  '2020/12/09'    109        133     195.1
# 9         60  '2020/12/10'     98        124     269.0
# 10        60  '2020/12/11'    103        147     329.3
# 11        60  '2020/12/12'    100        120     250.7
# 12        60  '2020/12/12'    100        120     250.7
# 13        60  '2020/12/13'    106        128     345.3
# 14        60  '2020/12/14'    104        132     379.3
# 15        60  '2020/12/15'     98        123     275.0
# ...

# %%
#dropping NA's values
df.dropna()
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 0         60  '2020/12/01'    110        130     409.1
# 1         60  '2020/12/02'    117        145     479.0
# 2         60  '2020/12/03'    103        135     340.0
# 3         45  '2020/12/04'    109        175     282.4
# 4         45  '2020/12/05'    117        148     406.0
# 5         60  '2020/12/06'    102        127     300.0
# 6         60  '2020/12/07'    110        136     374.0
# 7        450  '2020/12/08'    104        134     253.3
# 8         30  '2020/12/09'    109        133     195.1
# 9         60  '2020/12/10'     98        124     269.0
# 10        60  '2020/12/11'    103        147     329.3
# 11        60  '2020/12/12'    100        120     250.7
# 12        60  '2020/12/12'    100        120     250.7
# 13        60  '2020/12/13'    106        128     345.3
# 14        60  '2020/12/14'    104        132     379.3
# 15        60  '2020/12/15'     98        123     275.0
# ...

# %%
#dropping NA values from specific colum
df.dropna(subset=["Calories"])
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 0         60  '2020/12/01'    110        130     409.1
# 1         60  '2020/12/02'    117        145     479.0
# 2         60  '2020/12/03'    103        135     340.0
# 3         45  '2020/12/04'    109        175     282.4
# 4         45  '2020/12/05'    117        148     406.0
# 5         60  '2020/12/06'    102        127     300.0
# 6         60  '2020/12/07'    110        136     374.0
# 7        450  '2020/12/08'    104        134     253.3
# 8         30  '2020/12/09'    109        133     195.1
# 9         60  '2020/12/10'     98        124     269.0
# 10        60  '2020/12/11'    103        147     329.3
# 11        60  '2020/12/12'    100        120     250.7
# 12        60  '2020/12/12'    100        120     250.7
# 13        60  '2020/12/13'    106        128     345.3
# 14        60  '2020/12/14'    104        132     379.3
# 15        60  '2020/12/15'     98        123     275.0
# ...

# %%
#DataFrame.loc – Replace Values in Column based on Condition
#DataFrame.loc[condition, column_name] = new_value

# %%
df.loc[df["Duration"] > 50, ("Pulse")] = 99
df.loc[df["Duration"] > 50, "Duration"] = 100

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 0         60  '2020/12/01'    110        130     409.1
# 1         60  '2020/12/02'    117        145     479.0
# 2         60  '2020/12/03'    103        135     340.0
# 3         45  '2020/12/04'    109        175     282.4
# 4         45  '2020/12/05'    117        148     406.0
# 5         60  '2020/12/06'    102        127     300.0
# 6         60  '2020/12/07'    110        136     374.0
# 7        450  '2020/12/08'    104        134     253.3
# 8         30  '2020/12/09'    109        133     195.1
# 9         60  '2020/12/10'     98        124     269.0
# 10        60  '2020/12/11'    103        147     329.3
# 11        60  '2020/12/12'    100        120     250.7
# 12        60  '2020/12/12'    100        120     250.7
# 13        60  '2020/12/13'    106        128     345.3
# 14        60  '2020/12/14'    104        132     379.3
# 15        60  '2020/12/15'     98        123     275.0
# ...

# %%
#second method to replace value using numpy
#DataFrame['column_name'] = numpy.where(condition, new_value, DataFrame.column_name)

np.where(df["Duration"] > 100)
# Out:
# (array([7]),)

# %%
np.where(df["Duration"] > 100, 100, df.Duration)
# Out:
# array([ 60,  60,  60,  45,  45,  60,  60, 100,  30,  60,  60,  60,  60,
#         60,  60,  60,  60,  60,  45,  60,  45,  60,  45,  60,  45,  60,
#         60,  60,  60,  60,  60,  60])

# %%
df.Duration = np.where(df["Duration"] > 100, 100, df.Duration)

# %%
#sort values

# %%
df.sort_values(by = ["Duration", "Calories"], inplace = True)

# %%
df
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 8         30  '2020/12/09'    109        133     195.1
# 20        45  '2020/12/20'     97        125     243.0
# 24        45  '2020/12/24'    105        132     246.0
# 22        45           NaN    100        119     282.0
# 3         45  '2020/12/04'    109        175     282.4
# 4         45  '2020/12/05'    117        148     406.0
# 18        45  '2020/12/18'     90        112       NaN
# 16        60  '2020/12/16'     98        120     215.2
# 27        60  '2020/12/27'     92        118     241.0
# 31        60  '2020/12/31'     92        115     243.0
# 26        60      26/12/20    100        120     250.0
# 11        60  '2020/12/12'    100        120     250.7
# 12        60  '2020/12/12'    100        120     250.7
# 9         60  '2020/12/10'     98        124     269.0
# 15        60  '2020/12/15'     98        123     275.0
# 29        60  '2020/12/29'    100        132     280.0
# ...

# %%
#replacing NA values using condition
df.loc[df["Calories"].isna(), "Calories"] = 9999

# %%
#replacing NA values using fillna method
df = pd.read_csv(url)

# %%
df.Calories.fillna(10000, inplace = True)

# %%
df.Calories = df.Calories.fillna(1000)

# %%
df["Calories"] = df["Calores"].fillna(1000)

# %%
df["Calories"].fillna(df.Calories.mean(), inplace = True)

# %%
df
# Out:
#     Duration          Date  Pulse  Max Pulse  Calories
# 0         60  '2020/12/01'    110        130    409.10
# 1         60  '2020/12/02'    117        145    479.00
# 2         60  '2020/12/03'    103        135    340.00
# 3         45  '2020/12/04'    109        175    282.40
# 4         45  '2020/12/05'    117        148    406.00
# 5         60  '2020/12/06'    102        127    300.00
# 6         60  '2020/12/07'    110        136    374.00
# 7        450  '2020/12/08'    104        134    253.30
# 8         30  '2020/12/09'    109        133    195.10
# 9         60  '2020/12/10'     98        124    269.00
# 10        60  '2020/12/11'    103        147    329.30
# 11        60  '2020/12/12'    100        120    250.70
# 12        60  '2020/12/12'    100        120    250.70
# 13        60  '2020/12/13'    106        128    345.30
# 14        60  '2020/12/14'    104        132    379.30
# 15        60  '2020/12/15'     98        123    275.00
# ...

# %%
#getting column names
list(df.columns)
# Out:
# ['Duration', 'Date', 'Pulse', 'Max Pulse', 'Calories']

# %%
#getting date in proper format
df.Date = pd.to_datetime(df.Date)

# %%
df.loc[df.Date.isna(), "Date"] = "2020/12/31"

# %%
# Out:
#     Duration       Date  Pulse  Max Pulse  Calories
# 0         60 2020-12-01    110        130    409.10
# 1         60 2020-12-02    117        145    479.00
# 2         60 2020-12-03    103        135    340.00
# 3         45 2020-12-04    109        175    282.40
# 4         45 2020-12-05    117        148    406.00
# 5         60 2020-12-06    102        127    300.00
# 6         60 2020-12-07    110        136    374.00
# 7        450 2020-12-08    104        134    253.30
# 8         30 2020-12-09    109        133    195.10
# 9         60 2020-12-10     98        124    269.00
# 10        60 2020-12-11    103        147    329.30
# 11        60 2020-12-12    100        120    250.70
# 12        60 2020-12-12    100        120    250.70
# 13        60 2020-12-13    106        128    345.30
# 14        60 2020-12-14    104        132    379.30
# 15        60 2020-12-15     98        123    275.00
# 16        60 2020-12-16     98        120    215.20
# ...
